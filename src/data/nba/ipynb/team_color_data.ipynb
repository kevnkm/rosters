# %%
import requests
from bs4 import BeautifulSoup

# %%
nba_teams = [
  "Atlanta Hawks",
  "Boston Celtics",
  "Brooklyn Nets",
  "Charlotte Hornets",
  "Chicago Bulls",
  "Cleveland Cavaliers",
  "Dallas Mavericks",
  "Denver Nuggets",
  "Detroit Pistons",
  "Golden State Warriors",
  "Houston Rockets",
  "Indiana Pacers",
  "LA Clippers",
  "Los Angeles Lakers",
  "Memphis Grizzlies",
  "Miami Heat",
  "Milwaukee Bucks",
  "Minnesota Timberwolves",
  "New Orleans Pelicans",
  "New York Knicks",
  "Oklahoma City Thunder",
  "Orlando Magic",
  "Philadelphia 76ers",
  "Phoenix Suns",
  "Portland Trail Blazers",
  "Sacramento Kings",
  "San Antonio Spurs",
  "Toronto Raptors",
  "Utah Jazz",
  "Washington Wizards"
];

formatted_teams = [team.lower().replace(' ', '-') for team in nba_teams]

# %%
url = 'https://teamcolorcodes.com/atlanta-hawks-color-codes/'

response = requests.get(url)
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    colors_container = soup.find('div', class_='entry-content').findAll('div', class_='colorblock') #.findAdd('div', class_='color-card__cycle')

else:
    print("Failed to retrieve the page. Status code:", response.status_code)

# %%
colors = []
for card in colors_container:
        if card.has_attr('style'):
            style_declarations = card['style'].split(';')
            
            for declaration in style_declarations:
                if 'background-color' in declaration:
                    _, bg_color = declaration.split(':')
                    colors.append(bg_color.strip())
                    break
        else:
            print("Div without a style attribute.")

# %%
team_colors = []

for team in formatted_teams:
    url = f'https://teamcolorcodes.com/{team}-color-codes/'
    print(url)

    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        colors_container = soup.find('div', class_='entry-content').findAll('div', class_='colorblock') #.findAdd('div', class_='color-card__cycle')

    else:
        print("Failed to retrieve the page. Status code:", response.status_code)

    colors = []
    for card in colors_container:
            if card.has_attr('style'):
                style_declarations = card['style'].split(';')

                for declaration in style_declarations:
                    if 'background-color' in declaration:
                        _, bg_color = declaration.split(':')
                        colors.append(bg_color.strip())
                        break
            else:
                print("Div without a style attribute.")
                
    team_colors.append(colors)
# Out:
# https://teamcolorcodes.com/atlanta-hawks-color-codes/
# https://teamcolorcodes.com/boston-celtics-color-codes/
# Failed to retrieve the page. Status code: 403
# https://teamcolorcodes.com/brooklyn-nets-color-codes/
# https://teamcolorcodes.com/charlotte-hornets-color-codes/
# https://teamcolorcodes.com/chicago-bulls-color-codes/
# Failed to retrieve the page. Status code: 403
# https://teamcolorcodes.com/cleveland-cavaliers-color-codes/
# Failed to retrieve the page. Status code: 403
# https://teamcolorcodes.com/dallas-mavericks-color-codes/
# https://teamcolorcodes.com/denver-nuggets-color-codes/
# Failed to retrieve the page. Status code: 403
# https://teamcolorcodes.com/detroit-pistons-color-codes/
# Failed to retrieve the page. Status code: 403
# https://teamcolorcodes.com/golden-state-warriors-color-codes/
# https://teamcolorcodes.com/houston-rockets-color-codes/
# https://teamcolorcodes.com/indiana-pacers-color-codes/
# Failed to retrieve the page. Status code: 403
# ...

# %%
len(team_colors)
# Out:
# 30

# %%
nba_teams
# Out:
# ['Atlanta Hawks',
#  'Boston Celtics',
#  'Brooklyn Nets',
#  'Charlotte Hornets',
#  'Chicago Bulls',
#  'Cleveland Cavaliers',
#  'Dallas Mavericks',
#  'Denver Nuggets',
#  'Detroit Pistons',
#  'Golden State Warriors',
#  'Houston Rockets',
#  'Indiana Pacers',
#  'LA Clippers',
#  'Los Angeles Lakers',
#  'Memphis Grizzlies',
#  'Miami Heat',
#  'Milwaukee Bucks',
#  'Minnesota Timberwolves',
#  'New Orleans Pelicans',
#  'New York Knicks',
#  'Oklahoma City Thunder',
#  'Orlando Magic',
#  'Philadelphia 76ers',
#  'Phoenix Suns',
#  'Portland Trail Blazers',
#  'Sacramento Kings',
#  'San Antonio Spurs',
#  'Toronto Raptors',
#  'Utah Jazz',
#  'Washington Wizards']

# %%
team_colors
# Out:
# [['#C8102E',
#   '#FDB927',
#   '#000000',
#   '#9EA2A2',
#   '#FFFFFF',
#   '#e03a3e',
#   '#c1d32f',
#   '#26282a',
#   '#c8102e',
#   '#ffcd00',
#   '#87674f',
#   '#000'],
#  ['#C8102E',
#   '#FDB927',
#   '#000000',
#   '#9EA2A2',
#   '#FFFFFF',
#   '#e03a3e',
#   '#c1d32f',
#   '#26282a',
#   '#c8102e',
#   '#ffcd00',
#   '#87674f',
#   '#000'],
#  ['#000000', '#ffffff', '#002a60', '#cd1041', '#777d84', '#c6cfd4', '#ffffff'],
#  ['#1d1160', '#00788c', '#a1a1a4', '#00778b', '#280071', '#f9423a'],
#  ['#1d1160', '#00788c', '#a1a1a4', '#00778b', '#280071', '#f9423a'],
#  ['#1d1160', '#00788c', '#a1a1a4', '#00778b', '#280071', '#f9423a'],
#  ['#00538c', '#002b5e', '#b8c4ca', '#000000', '#002855', '#00843d'],
#  ['#00538c', '#002b5e', '#b8c4ca', '#000000', '#002855', '#00843d'],
#  ['#00538c', '#002b5e', '#b8c4ca', '#000000', '#002855', '#00843d'],
#  ['#1d428a',
#   '#1d428a',
#   '#1d428a',
#   '#ffc72c',
#   '#ffc72c',
#   '#006bb6',
#   '#fdb927',
#   '#fdb927',
#   '#26282a',
# ...

# %%
import json

# %%
combined_dict = dict(zip(nba_teams, team_colors))

# Convert the dictionary to a JSON-formatted string
json_string = json.dumps(combined_dict, indent=2)

# Print the JSON string
print(json_string)
# Out:
# {
#   "Atlanta Hawks": [
#     "#C8102E",
#     "#FDB927",
#     "#000000",
#     "#9EA2A2",
#     "#FFFFFF",
#     "#e03a3e",
#     "#c1d32f",
#     "#26282a",
#     "#c8102e",
#     "#ffcd00",
#     "#87674f",
#     "#000"
#   ],
#   "Boston Celtics": [
#     "#C8102E",
#     "#FDB927",
#     "#000000",
#     "#9EA2A2",
#     "#FFFFFF",
#     "#e03a3e",
#     "#c1d32f",
#     "#26282a",
#     "#c8102e",
#     "#ffcd00",
#     "#87674f",
#     "#000"
#   ],
#   "Brooklyn Nets": [
#     "#000000",
#     "#ffffff",
#     "#002a60",
#     "#cd1041",
#     "#777d84",
#     "#c6cfd4",
#     "#ffffff"
#   ],
#   "Charlotte Hornets": [
#     "#1d1160",
#     "#00788c",
#     "#a1a1a4",
#     "#00778b",
#     "#280071",
#     "#f9423a"
#   ],
#   "Chicago Bulls": [
#     "#1d1160",
#     "#00788c",
#     "#a1a1a4",
#     "#00778b",
#     "#280071",
#     "#f9423a"
#   ],
#   "Cleveland Cavaliers": [
#     "#1d1160",
#     "#00788c",
#     "#a1a1a4",
#     "#00778b",
#     "#280071",
# ...

# %%
file_path = "team_colors.json"

# Write the JSON string to a file
with open(file_path, 'w') as json_file:
    json.dump(combined_dict, json_file, indent=2)

print(f"JSON data has been exported to {file_path}")
# Out:
# JSON data has been exported to team_colors.json
